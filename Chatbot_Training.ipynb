# %% [markdown]
# # Chatbot using Seq2Seq LSTM models
# In this notebook, we will assemble a seq2seq LSTM model using Keras Functional API to create a working Chatbot which would answer questions asked to it.
#
# Chatbots have become applications themselves. You can choose the field or stream and gather data regarding various questions. We can build a chatbot for an e-commerce webiste or a school website where parents could get information about the school.
#
#
# Messaging platforms like Allo have implemented chatbot services to engage users. The famous [Google Assistant](https://assistant.google.com/), [Siri](https://www.apple.com/in/siri/), [Cortana](https://www.microsoft.com/en-in/windows/cortana) and [Alexa](https://www.alexa.com/) may have been build using simialr models.
#
# So, let's start building our Chatbot.

# %% [markdown]
# ## 1) Importing the packages
#
# We will import [TensorFlow](https://www.tensorflow.org) and our beloved [Keras](https://www.tensorflow.org/guide/keras). Also, we import other modules which help in defining model layers.

# %%
import numpy as np
import tensorflow as tf
import pickle
import matplotlib.pyplot as plt
import glob
from tensorflow.keras import layers , activations , models , preprocessing

# %%
from tensorflow.keras import preprocessing , utils
import os
import yaml

# dir_path = './Datasets'

questions = list()
answers = list()

for filepath in glob.glob('./Datasets/*.yml'):
    stream = open( filepath , 'rb')
    docs = yaml.safe_load(stream)
    conversations = docs['conversations']
    for con in conversations:
        if len( con ) > 2 :
            questions.append(con[0])
            replies = con[ 1 : ]
            ans = ''
            for rep in replies:
                ans += ' ' + rep
            answers.append( ans )
        elif len( con )> 1:
            questions.append(con[0])
            answers.append(con[1])

answers_with_tags = list()
for i in range( len( answers ) ):
    if type( answers[i] ) == str:
        answers_with_tags.append( answers[i] )
    else:
        questions.pop( i )

answers = list()
for i in range( len( answers_with_tags ) ) :
    answers.append( '<START> ' + answers_with_tags[i] + ' <END>' )

tokenizer = preprocessing.text.Tokenizer()
tokenizer.fit_on_texts( questions + answers )
VOCAB_SIZE = len( tokenizer.word_index )+1
print( 'VOCAB SIZE : {}'.format( VOCAB_SIZE ))
# Out:
# VOCAB SIZE : 1448

# %%
import pickle

with open('tokenizer.pkl', 'wb') as f:
    pickle.dump(tokenizer, f)

# %% [markdown]
# ### C) Preparing data for Seq2Seq model
#
# Our model requires three arrays namely `encoder_input_data`, `decoder_input_data` and `decoder_output_data`.
#
# For `encoder_input_data` :
# * Tokenize the `questions`. Pad them to their maximum length.
#
# For `decoder_input_data` :
# * Tokenize the `answers`. Pad them to their maximum length.
#
# For `decoder_output_data` :
#
# * Tokenize the `answers`. Remove the first element from all the `tokenized_answers`. This is the `<START>` element which we added earlier.

# %%
from gensim.models import Word2Vec
import re

vocab = []
for word in tokenizer.word_index:
    vocab.append( word )

def tokenize( sentences ):
    tokens_list = []
    vocabulary = []
    for sentence in sentences:
        sentence = sentence.lower()
        sentence = re.sub( '[^a-zA-Z]', ' ', sentence )
        tokens = sentence.split()
        vocabulary += tokens
        tokens_list.append( tokens )
    return tokens_list , vocabulary

#p = tokenize( questions + answers )
#model = Word2Vec( p[ 0 ] ) 

#embedding_matrix = np.zeros( ( VOCAB_SIZE , 100 ) )
#for i in range( len( tokenizer.word_index ) ):
    #embedding_matrix[ i ] = model[ vocab[i] ]

# encoder_input_data
tokenized_questions = tokenizer.texts_to_sequences( questions )
maxlen_questions = max( [ len(x) for x in tokenized_questions ] )
padded_questions = preprocessing.sequence.pad_sequences( tokenized_questions , maxlen=maxlen_questions , padding='post' )
encoder_input_data = np.array( padded_questions )
print( encoder_input_data.shape , maxlen_questions )

# decoder_input_data
tokenized_answers = tokenizer.texts_to_sequences( answers )
maxlen_answers = max( [ len(x) for x in tokenized_answers ] )
padded_answers = preprocessing.sequence.pad_sequences( tokenized_answers , maxlen=maxlen_answers , padding='post' )
decoder_input_data = np.array( padded_answers )
print( decoder_input_data.shape , maxlen_answers )

# decoder_output_data
tokenized_answers = tokenizer.texts_to_sequences( answers )
for i in range(len(tokenized_answers)) :
    tokenized_answers[i] = tokenized_answers[i][1:]
padded_answers = preprocessing.sequence.pad_sequences( tokenized_answers , maxlen=maxlen_answers , padding='post' )
onehot_answers = utils.to_categorical( padded_answers , VOCAB_SIZE )
decoder_output_data = np.array( onehot_answers )
print( decoder_output_data.shape )
# Out:
# (806, 13) 13
# (806, 85) 85
# (806, 85, 1448)

# %%
from sklearn.model_selection import train_test_split

# Split the data into training and validation sets
encoder_input_train, encoder_input_val, decoder_input_train, decoder_input_val, decoder_output_train, decoder_output_val = train_test_split(encoder_input_data, decoder_input_data, decoder_output_data, test_size=0.15,random_state=42)

print("Shape of encoder_input_train:", encoder_input_train.shape)
print("Shape of encoder_input_val:", encoder_input_val.shape)
print("Shape of decoder_input_train:", decoder_input_train.shape)
print("Shape of decoder_input_val:", decoder_input_val.shape)
print("Shape of decoder_output_train:", decoder_output_train.shape)
print("Shape of decoder_output_val:", decoder_output_val.shape)
# Out:
# Shape of encoder_input_train: (685, 13)
# Shape of encoder_input_val: (121, 13)
# Shape of decoder_input_train: (685, 85)
# Shape of decoder_input_val: (121, 85)
# Shape of decoder_output_train: (685, 85, 1448)
# Shape of decoder_output_val: (121, 85, 1448)

# %% [markdown]
# ## 3) Defining the Encoder-Decoder model
# The model will have Embedding, LSTM and Dense layers. The basic configuration is as follows.
#
#
# *   2 Input Layers : One for `encoder_input_data` and another for `decoder_input_data`.
# *   Embedding layer : For converting token vectors to fix sized dense vectors. **( Note :  Don't forget the `mask_zero=True` argument here )**
# *   LSTM layer : Provide access to Long-Short Term cells.
#
# Working :
#
# 1.   The `encoder_input_data` comes in the Embedding layer (  `encoder_embedding` ).
# 2.   The output of the Embedding layer goes to the LSTM cell which produces 2 state vectors ( `h` and `c` which are `encoder_states` )
# 3.   These states are set in the LSTM cell of the decoder.
# 4.   The decoder_input_data comes in through the Embedding layer.
# 5.   The Embeddings goes in LSTM cell ( which had the states ) to produce seqeunces.
#
#
#
# <center><img style="float: center;" src="https://cdn-images-1.medium.com/max/1600/1*bnRvZDDapHF8Gk8soACtCQ.gif"></center>
#
#
# Image credits to [Hackernoon](https://hackernoon.com/tutorial-3-what-is-seq2seq-for-text-summarization-and-why-68ebaa644db0).

# %%
encoder_inputs = tf.keras.layers.Input(shape=( maxlen_questions , ))
encoder_embedding = tf.keras.layers.Embedding( VOCAB_SIZE, 200 , mask_zero=True ) (encoder_inputs)
encoder_outputs , state_h , state_c = tf.keras.layers.LSTM( 200 , return_state=True )( encoder_embedding )
encoder_states = [ state_h , state_c ]

decoder_inputs = tf.keras.layers.Input(shape=( maxlen_answers ,  ))
decoder_embedding = tf.keras.layers.Embedding( VOCAB_SIZE, 200 , mask_zero=True) (decoder_inputs)
decoder_lstm = tf.keras.layers.LSTM( 200 , return_state=True , return_sequences=True )
decoder_outputs , _ , _ = decoder_lstm ( decoder_embedding , initial_state=encoder_states )
decoder_dense = tf.keras.layers.Dense( VOCAB_SIZE , activation=tf.keras.activations.softmax ) 
output = decoder_dense ( decoder_outputs )

model = tf.keras.models.Model([encoder_inputs, decoder_inputs], output )
model.compile(optimizer=tf.keras.optimizers.Adam(), loss='categorical_crossentropy',metrics=['accuracy'])

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 13)]         0           []
#
#  input_2 (InputLayer)           [(None, 85)]         0           []
#
#  embedding (Embedding)          (None, 13, 200)      289600      ['input_1[0][0]']
#
#  embedding_1 (Embedding)        (None, 85, 200)      289600      ['input_2[0][0]']
#
#  lstm (LSTM)                    [(None, 200),        320800      ['embedding[0][0]']
#                                  (None, 200),
#                                  (None, 200)]
#
#  lstm_1 (LSTM)                  [(None, 85, 200),    320800      ['embedding_1[0][0]',
#                                  (None, 200),                     'lstm[0][1]',
#                                  (None, 200)]                     'lstm[0][2]']
#
#  dense (Dense)                  (None, 85, 1448)     291048      ['lstm_1[0][0]']
#
# ==================================================================================================
# Total params: 1,511,848
# Trainable params: 1,511,848
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath="LSTM.h5",
    monitor='val_loss',
    verbose=1)

early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', # Metric to monitor
    patience=5, # Number of epochs with no improvement after which training will be stopped
    verbose=1
)

# %%
history = model.fit([encoder_input_train , decoder_input_train], decoder_output_train,validation_data=([encoder_input_val , decoder_input_val],decoder_output_val), batch_size=64, epochs=250,callbacks=[checkpoint_callback,early_stopping] )
# Out:
# Epoch 1/250
# 10/11 [==========================>...] - ETA: 0s - loss: 2.1539 - accuracy: 0.0652
# Epoch 1: saving model to LSTM.h5
# 11/11 [==============================] - 12s 260ms/step - loss: 2.1446 - accuracy: 0.0650 - val_loss: 1.7919 - val_accuracy: 0.0593
# Epoch 2/250
# 10/11 [==========================>...] - ETA: 0s - loss: 1.8789 - accuracy: 0.0585
# Epoch 2: saving model to LSTM.h5
# 11/11 [==============================] - 1s 61ms/step - loss: 1.8622 - accuracy: 0.0586 - val_loss: 1.4924 - val_accuracy: 0.0519
# Epoch 3/250
# 11/11 [==============================] - ETA: 0s - loss: 1.7198 - accuracy: 0.0519
# Epoch 3: saving model to LSTM.h5
# 11/11 [==============================] - 1s 55ms/step - loss: 1.7198 - accuracy: 0.0519 - val_loss: 1.4809 - val_accuracy: 0.0720
# Epoch 4/250
# 11/11 [==============================] - ETA: 0s - loss: 1.6947 - accuracy: 0.0582
# Epoch 4: saving model to LSTM.h5
# 11/11 [==============================] - 1s 57ms/step - loss: 1.6947 - accuracy: 0.0582 - val_loss: 1.4749 - val_accuracy: 0.0519
# Epoch 5/250
# 11/11 [==============================] - ETA: 0s - loss: 1.6836 - accuracy: 0.0579
# Epoch 5: saving model to LSTM.h5
# 11/11 [==============================] - 1s 47ms/step - loss: 1.6836 - accuracy: 0.0579 - val_loss: 1.4655 - val_accuracy: 0.0877
# Epoch 6/250
# 11/11 [==============================] - ETA: 0s - loss: 1.6712 - accuracy: 0.0932
# Epoch 6: saving model to LSTM.h5
# 11/11 [==============================] - 1s 48ms/step - loss: 1.6712 - accuracy: 0.0932 - val_loss: 1.4558 - val_accuracy: 0.0966
# Epoch 7/250
# 11/11 [==============================] - ETA: 0s - loss: 1.6567 - accuracy: 0.0968
# Epoch 7: saving model to LSTM.h5
# 11/11 [==============================] - 1s 49ms/step - loss: 1.6567 - accuracy: 0.0968 - val_loss: 1.4400 - val_accuracy: 0.0966
# Epoch 8/250
# 11/11 [==============================] - ETA: 0s - loss: 1.6369 - accuracy: 0.0970
# Epoch 8: saving model to LSTM.h5
# 11/11 [==============================] - 1s 49ms/step - loss: 1.6369 - accuracy: 0.0970 - val_loss: 1.4211 - val_accuracy: 0.0970
# Epoch 9/250
# 11/11 [==============================] - ETA: 0s - loss: 1.6122 - accuracy: 0.0961
# Epoch 9: saving model to LSTM.h5
# 11/11 [==============================] - 1s 54ms/step - loss: 1.6122 - accuracy: 0.0961 - val_loss: 1.3976 - val_accuracy: 0.0981
# Epoch 10/250
# 11/11 [==============================] - ETA: 0s - loss: 1.5850 - accuracy: 0.0969
# Epoch 10: saving model to LSTM.h5
# 11/11 [==============================] - 1s 49ms/step - loss: 1.5850 - accuracy: 0.0969 - val_loss: 1.3761 - val_accuracy: 0.1063
# Epoch 11/250
# 11/11 [==============================] - ETA: 0s - loss: 1.5561 - accuracy: 0.1084
# Epoch 11: saving model to LSTM.h5
# 11/11 [==============================] - 1s 47ms/step - loss: 1.5561 - accuracy: 0.1084 - val_loss: 1.3476 - val_accuracy: 0.1190
# Epoch 12/250
# 11/11 [==============================] - ETA: 0s - loss: 1.5253 - accuracy: 0.1223
# Epoch 12: saving model to LSTM.h5
# 11/11 [==============================] - 1s 48ms/step - loss: 1.5253 - accuracy: 0.1223 - val_loss: 1.3238 - val_accuracy: 0.1354
# Epoch 13/250
# 11/11 [==============================] - ETA: 0s - loss: 1.4946 - accuracy: 0.1407
# Epoch 13: saving model to LSTM.h5
# 11/11 [==============================] - 1s 48ms/step - loss: 1.4946 - accuracy: 0.1407 - val_loss: 1.2981 - val_accuracy: 0.1601
# Epoch 14/250
# 11/11 [==============================] - ETA: 0s - loss: 1.4643 - accuracy: 0.1677
# Epoch 14: saving model to LSTM.h5
# 11/11 [==============================] - 1s 48ms/step - loss: 1.4643 - accuracy: 0.1677 - val_loss: 1.2729 - val_accuracy: 0.1821
# Epoch 15/250
# 10/11 [==========================>...] - ETA: 0s - loss: 1.4440 - accuracy: 0.1895
# Epoch 15: saving model to LSTM.h5
# 11/11 [==============================] - 1s 52ms/step - loss: 1.4318 - accuracy: 0.1901 - val_loss: 1.2458 - val_accuracy: 0.2082
# Epoch 16/250
# 11/11 [==============================] - ETA: 0s - loss: 1.3986 - accuracy: 0.2058
# Epoch 16: saving model to LSTM.h5
# 11/11 [==============================] - 1s 52ms/step - loss: 1.3986 - accuracy: 0.2058 - val_loss: 1.2182 - val_accuracy: 0.2231
# Epoch 17/250
# 11/11 [==============================] - ETA: 0s - loss: 1.3652 - accuracy: 0.2286
# Epoch 17: saving model to LSTM.h5
# 11/11 [==============================] - 1s 50ms/step - loss: 1.3652 - accuracy: 0.2286 - val_loss: 1.1892 - val_accuracy: 0.2369
# Epoch 18/250
# 11/11 [==============================] - ETA: 0s - loss: 1.3306 - accuracy: 0.2432
# Epoch 18: saving model to LSTM.h5
# 11/11 [==============================] - 1s 49ms/step - loss: 1.3306 - accuracy: 0.2432 - val_loss: 1.1596 - val_accuracy: 0.2425
# Epoch 19/250
# 11/11 [==============================] - ETA: 0s - loss: 1.2948 - accuracy: 0.2517
# Epoch 19: saving model to LSTM.h5
# 11/11 [==============================] - 1s 51ms/step - loss: 1.2948 - accuracy: 0.2517 - val_loss: 1.1319 - val_accuracy: 0.2496
# Epoch 20/250
# 11/11 [==============================] - ETA: 0s - loss: 1.2592 - accuracy: 0.2625
# Epoch 20: saving model to LSTM.h5
# 11/11 [==============================] - 1s 51ms/step - loss: 1.2592 - accuracy: 0.2625 - val_loss: 1.1024 - val_accuracy: 0.2675
# Epoch 21/250
# 11/11 [==============================] - ETA: 0s - loss: 1.2239 - accuracy: 0.2815
# Epoch 21: saving model to LSTM.h5
# 11/11 [==============================] - 1s 49ms/step - loss: 1.2239 - accuracy: 0.2815 - val_loss: 1.0714 - val_accuracy: 0.2910
# Epoch 22/250
# 11/11 [==============================] - ETA: 0s - loss: 1.1877 - accuracy: 0.2985
# Epoch 22: saving model to LSTM.h5
# 11/11 [==============================] - 1s 50ms/step - loss: 1.1877 - accuracy: 0.2985 - val_loss: 1.0427 - val_accuracy: 0.3104
# Epoch 23/250
# 11/11 [==============================] - ETA: 0s - loss: 1.1521 - accuracy: 0.3090
# Epoch 23: saving model to LSTM.h5
# 11/11 [==============================] - 1s 51ms/step - loss: 1.1521 - accuracy: 0.3090 - val_loss: 1.0137 - val_accuracy: 0.3153
# Epoch 24/250
# 11/11 [==============================] - ETA: 0s - loss: 1.1178 - accuracy: 0.3180
# Epoch 24: saving model to LSTM.h5
# 11/11 [==============================] - 1s 51ms/step - loss: 1.1178 - accuracy: 0.3180 - val_loss: 0.9864 - val_accuracy: 0.3321
# Epoch 25/250
# 10/11 [==========================>...] - ETA: 0s - loss: 1.0751 - accuracy: 0.3326
# Epoch 25: saving model to LSTM.h5
# 11/11 [==============================] - 1s 53ms/step - loss: 1.0843 - accuracy: 0.3331 - val_loss: 0.9616 - val_accuracy: 0.3422
# Epoch 26/250
# 11/11 [==============================] - ETA: 0s - loss: 1.0516 - accuracy: 0.3475
# Epoch 26: saving model to LSTM.h5
# 11/11 [==============================] - 1s 52ms/step - loss: 1.0516 - accuracy: 0.3475 - val_loss: 0.9371 - val_accuracy: 0.3567
# Epoch 27/250
# 11/11 [==============================] - ETA: 0s - loss: 1.0207 - accuracy: 0.3631
# Epoch 27: saving model to LSTM.h5
# 11/11 [==============================] - 1s 51ms/step - loss: 1.0207 - accuracy: 0.3631 - val_loss: 0.9133 - val_accuracy: 0.3746
# Epoch 28/250
# 11/11 [==============================] - ETA: 0s - loss: 0.9903 - accuracy: 0.3784
# Epoch 28: saving model to LSTM.h5
# 11/11 [==============================] - 1s 53ms/step - loss: 0.9903 - accuracy: 0.3784 - val_loss: 0.8912 - val_accuracy: 0.3836
# Epoch 29/250
# 11/11 [==============================] - ETA: 0s - loss: 0.9617 - accuracy: 0.3892
# Epoch 29: saving model to LSTM.h5
# 11/11 [==============================] - 1s 52ms/step - loss: 0.9617 - accuracy: 0.3892 - val_loss: 0.8724 - val_accuracy: 0.3922
# Epoch 30/250
# 11/11 [==============================] - ETA: 0s - loss: 0.9340 - accuracy: 0.4026
# Epoch 30: saving model to LSTM.h5
# 11/11 [==============================] - 1s 51ms/step - loss: 0.9340 - accuracy: 0.4026 - val_loss: 0.8512 - val_accuracy: 0.4052
# Epoch 31/250
# 11/11 [==============================] - ETA: 0s - loss: 0.9069 - accuracy: 0.4149
# Epoch 31: saving model to LSTM.h5
# 11/11 [==============================] - 1s 50ms/step - loss: 0.9069 - accuracy: 0.4149 - val_loss: 0.8311 - val_accuracy: 0.4134
# Epoch 32/250
# 11/11 [==============================] - ETA: 0s - loss: 0.8810 - accuracy: 0.4229
# Epoch 32: saving model to LSTM.h5
# 11/11 [==============================] - 1s 56ms/step - loss: 0.8810 - accuracy: 0.4229 - val_loss: 0.8122 - val_accuracy: 0.4153
# Epoch 33/250
# 11/11 [==============================] - ETA: 0s - loss: 0.8561 - accuracy: 0.4325
# Epoch 33: saving model to LSTM.h5
# 11/11 [==============================] - 1s 49ms/step - loss: 0.8561 - accuracy: 0.4325 - val_loss: 0.7955 - val_accuracy: 0.4276
# Epoch 34/250
# 11/11 [==============================] - ETA: 0s - loss: 0.8321 - accuracy: 0.4430
# Epoch 34: saving model to LSTM.h5
# 11/11 [==============================] - 1s 58ms/step - loss: 0.8321 - accuracy: 0.4430 - val_loss: 0.7772 - val_accuracy: 0.4351
# Epoch 35/250
# 11/11 [==============================] - ETA: 0s - loss: 0.8095 - accuracy: 0.4507
# Epoch 35: saving model to LSTM.h5
# 11/11 [==============================] - 1s 55ms/step - loss: 0.8095 - accuracy: 0.4507 - val_loss: 0.7614 - val_accuracy: 0.4466
# Epoch 36/250
# 11/11 [==============================] - ETA: 0s - loss: 0.7873 - accuracy: 0.4652
# Epoch 36: saving model to LSTM.h5
# 11/11 [==============================] - 1s 55ms/step - loss: 0.7873 - accuracy: 0.4652 - val_loss: 0.7452 - val_accuracy: 0.4541
# Epoch 37/250
# 11/11 [==============================] - ETA: 0s - loss: 0.7653 - accuracy: 0.4732
# Epoch 37: saving model to LSTM.h5
# 11/11 [==============================] - 1s 53ms/step - loss: 0.7653 - accuracy: 0.4732 - val_loss: 0.7307 - val_accuracy: 0.4608
# Epoch 38/250
# 10/11 [==========================>...] - ETA: 0s - loss: 0.7453 - accuracy: 0.4843
# Epoch 38: saving model to LSTM.h5
# 11/11 [==============================] - 1s 61ms/step - loss: 0.7449 - accuracy: 0.4845 - val_loss: 0.7186 - val_accuracy: 0.4694
# Epoch 39/250
# 11/11 [==============================] - ETA: 0s - loss: 0.7255 - accuracy: 0.4977
# Epoch 39: saving model to LSTM.h5
# 11/11 [==============================] - 1s 52ms/step - loss: 0.7255 - accuracy: 0.4977 - val_loss: 0.7026 - val_accuracy: 0.4884
# Epoch 40/250
# 11/11 [==============================] - ETA: 0s - loss: 0.7062 - accuracy: 0.5075
# Epoch 40: saving model to LSTM.h5
# 11/11 [==============================] - 1s 51ms/step - loss: 0.7062 - accuracy: 0.5075 - val_loss: 0.6894 - val_accuracy: 0.4966
# Epoch 41/250
# 10/11 [==========================>...] - ETA: 0s - loss: 0.6859 - accuracy: 0.5194
# Epoch 41: saving model to LSTM.h5
# 11/11 [==============================] - 1s 55ms/step - loss: 0.6879 - accuracy: 0.5196 - val_loss: 0.6782 - val_accuracy: 0.5052
# Epoch 42/250
# 11/11 [==============================] - ETA: 0s - loss: 0.6701 - accuracy: 0.5280
# Epoch 42: saving model to LSTM.h5
# 11/11 [==============================] - 1s 50ms/step - loss: 0.6701 - accuracy: 0.5280 - val_loss: 0.6670 - val_accuracy: 0.5127
# Epoch 43/250
# 11/11 [==============================] - ETA: 0s - loss: 0.6537 - accuracy: 0.5376
# Epoch 43: saving model to LSTM.h5
# 11/11 [==============================] - 1s 65ms/step - loss: 0.6537 - accuracy: 0.5376 - val_loss: 0.6553 - val_accuracy: 0.5187
# Epoch 44/250
# 11/11 [==============================] - ETA: 0s - loss: 0.6363 - accuracy: 0.5458
# Epoch 44: saving model to LSTM.h5
# 11/11 [==============================] - 1s 55ms/step - loss: 0.6363 - accuracy: 0.5458 - val_loss: 0.6451 - val_accuracy: 0.5340
# Epoch 45/250
# 11/11 [==============================] - ETA: 0s - loss: 0.6203 - accuracy: 0.5549
# Epoch 45: saving model to LSTM.h5
# 11/11 [==============================] - 1s 50ms/step - loss: 0.6203 - accuracy: 0.5549 - val_loss: 0.6330 - val_accuracy: 0.5377
# Epoch 46/250
# 11/11 [==============================] - ETA: 0s - loss: 0.6047 - accuracy: 0.5637
# Epoch 46: saving model to LSTM.h5
# 11/11 [==============================] - 1s 47ms/step - loss: 0.6047 - accuracy: 0.5637 - val_loss: 0.6245 - val_accuracy: 0.5481
# Epoch 47/250
# 11/11 [==============================] - ETA: 0s - loss: 0.5893 - accuracy: 0.5739
# Epoch 47: saving model to LSTM.h5
# 11/11 [==============================] - 1s 52ms/step - loss: 0.5893 - accuracy: 0.5739 - val_loss: 0.6142 - val_accuracy: 0.5549
# Epoch 48/250
# 11/11 [==============================] - ETA: 0s - loss: 0.5747 - accuracy: 0.5800
# Epoch 48: saving model to LSTM.h5
# 11/11 [==============================] - 1s 51ms/step - loss: 0.5747 - accuracy: 0.5800 - val_loss: 0.6056 - val_accuracy: 0.5627
# Epoch 49/250
# 11/11 [==============================] - ETA: 0s - loss: 0.5601 - accuracy: 0.5885
# Epoch 49: saving model to LSTM.h5
# 11/11 [==============================] - 1s 50ms/step - loss: 0.5601 - accuracy: 0.5885 - val_loss: 0.5943 - val_accuracy: 0.5679
# Epoch 50/250
# 11/11 [==============================] - ETA: 0s - loss: 0.5471 - accuracy: 0.5943
# Epoch 50: saving model to LSTM.h5
# 11/11 [==============================] - 1s 50ms/step - loss: 0.5471 - accuracy: 0.5943 - val_loss: 0.5882 - val_accuracy: 0.5754
# Epoch 51/250
# 11/11 [==============================] - ETA: 0s - loss: 0.5330 - accuracy: 0.6054
# Epoch 51: saving model to LSTM.h5
# 11/11 [==============================] - 1s 49ms/step - loss: 0.5330 - accuracy: 0.6054 - val_loss: 0.5798 - val_accuracy: 0.5840
# Epoch 52/250
# 11/11 [==============================] - ETA: 0s - loss: 0.5208 - accuracy: 0.6125
# Epoch 52: saving model to LSTM.h5
# 11/11 [==============================] - 1s 49ms/step - loss: 0.5208 - accuracy: 0.6125 - val_loss: 0.5708 - val_accuracy: 0.5910
# Epoch 53/250
# 11/11 [==============================] - ETA: 0s - loss: 0.5081 - accuracy: 0.6191
# Epoch 53: saving model to LSTM.h5
# 11/11 [==============================] - 1s 49ms/step - loss: 0.5081 - accuracy: 0.6191 - val_loss: 0.5651 - val_accuracy: 0.5910
# Epoch 54/250
# 11/11 [==============================] - ETA: 0s - loss: 0.4958 - accuracy: 0.6249
# Epoch 54: saving model to LSTM.h5
# 11/11 [==============================] - 1s 49ms/step - loss: 0.4958 - accuracy: 0.6249 - val_loss: 0.5569 - val_accuracy: 0.5981
# Epoch 55/250
# 11/11 [==============================] - ETA: 0s - loss: 0.4837 - accuracy: 0.6352
# Epoch 55: saving model to LSTM.h5
# 11/11 [==============================] - 1s 48ms/step - loss: 0.4837 - accuracy: 0.6352 - val_loss: 0.5484 - val_accuracy: 0.6101
# Epoch 56/250
# 11/11 [==============================] - ETA: 0s - loss: 0.4716 - accuracy: 0.6435
# Epoch 56: saving model to LSTM.h5
# 11/11 [==============================] - 1s 50ms/step - loss: 0.4716 - accuracy: 0.6435 - val_loss: 0.5422 - val_accuracy: 0.6146
# Epoch 57/250
# 11/11 [==============================] - ETA: 0s - loss: 0.4601 - accuracy: 0.6530
# Epoch 57: saving model to LSTM.h5
# 11/11 [==============================] - 1s 49ms/step - loss: 0.4601 - accuracy: 0.6530 - val_loss: 0.5354 - val_accuracy: 0.6209
# Epoch 58/250
# 11/11 [==============================] - ETA: 0s - loss: 0.4491 - accuracy: 0.6591
# Epoch 58: saving model to LSTM.h5
# 11/11 [==============================] - 1s 50ms/step - loss: 0.4491 - accuracy: 0.6591 - val_loss: 0.5285 - val_accuracy: 0.6254
# Epoch 59/250
# 11/11 [==============================] - ETA: 0s - loss: 0.4380 - accuracy: 0.6672
# Epoch 59: saving model to LSTM.h5
# 11/11 [==============================] - 1s 50ms/step - loss: 0.4380 - accuracy: 0.6672 - val_loss: 0.5235 - val_accuracy: 0.6369
# Epoch 60/250
# 11/11 [==============================] - ETA: 0s - loss: 0.4274 - accuracy: 0.6758
# Epoch 60: saving model to LSTM.h5
# 11/11 [==============================] - 1s 48ms/step - loss: 0.4274 - accuracy: 0.6758 - val_loss: 0.5161 - val_accuracy: 0.6440
# Epoch 61/250
# 11/11 [==============================] - ETA: 0s - loss: 0.4170 - accuracy: 0.6821
# Epoch 61: saving model to LSTM.h5
# 11/11 [==============================] - 1s 50ms/step - loss: 0.4170 - accuracy: 0.6821 - val_loss: 0.5140 - val_accuracy: 0.6455
# Epoch 62/250
# 11/11 [==============================] - ETA: 0s - loss: 0.4073 - accuracy: 0.6911
# Epoch 62: saving model to LSTM.h5
# 11/11 [==============================] - 1s 48ms/step - loss: 0.4073 - accuracy: 0.6911 - val_loss: 0.5059 - val_accuracy: 0.6590
# Epoch 63/250
# 11/11 [==============================] - ETA: 0s - loss: 0.3974 - accuracy: 0.6992
# Epoch 63: saving model to LSTM.h5
# 11/11 [==============================] - 1s 47ms/step - loss: 0.3974 - accuracy: 0.6992 - val_loss: 0.5014 - val_accuracy: 0.6657
# Epoch 64/250
# 11/11 [==============================] - ETA: 0s - loss: 0.3874 - accuracy: 0.7106
# Epoch 64: saving model to LSTM.h5
# 11/11 [==============================] - 1s 48ms/step - loss: 0.3874 - accuracy: 0.7106 - val_loss: 0.4957 - val_accuracy: 0.6743
# Epoch 65/250
# 11/11 [==============================] - ETA: 0s - loss: 0.3777 - accuracy: 0.7177
# Epoch 65: saving model to LSTM.h5
# 11/11 [==============================] - 1s 48ms/step - loss: 0.3777 - accuracy: 0.7177 - val_loss: 0.4910 - val_accuracy: 0.6806
# Epoch 66/250
# 11/11 [==============================] - ETA: 0s - loss: 0.3684 - accuracy: 0.7262
# Epoch 66: saving model to LSTM.h5
# 11/11 [==============================] - 1s 48ms/step - loss: 0.3684 - accuracy: 0.7262 - val_loss: 0.4867 - val_accuracy: 0.6884
# Epoch 67/250
# 11/11 [==============================] - ETA: 0s - loss: 0.3592 - accuracy: 0.7355
# Epoch 67: saving model to LSTM.h5
# 11/11 [==============================] - 1s 49ms/step - loss: 0.3592 - accuracy: 0.7355 - val_loss: 0.4819 - val_accuracy: 0.6925
# Epoch 68/250
# 11/11 [==============================] - ETA: 0s - loss: 0.3515 - accuracy: 0.7427
# Epoch 68: saving model to LSTM.h5
# 11/11 [==============================] - 1s 49ms/step - loss: 0.3515 - accuracy: 0.7427 - val_loss: 0.4770 - val_accuracy: 0.6989
# Epoch 69/250
# 11/11 [==============================] - ETA: 0s - loss: 0.3436 - accuracy: 0.7505
# Epoch 69: saving model to LSTM.h5
# 11/11 [==============================] - 1s 47ms/step - loss: 0.3436 - accuracy: 0.7505 - val_loss: 0.4720 - val_accuracy: 0.7030
# Epoch 70/250
# 11/11 [==============================] - ETA: 0s - loss: 0.3345 - accuracy: 0.7566
# Epoch 70: saving model to LSTM.h5
# 11/11 [==============================] - 1s 48ms/step - loss: 0.3345 - accuracy: 0.7566 - val_loss: 0.4691 - val_accuracy: 0.7078
# Epoch 71/250
# 11/11 [==============================] - ETA: 0s - loss: 0.3262 - accuracy: 0.7645
# Epoch 71: saving model to LSTM.h5
# 11/11 [==============================] - 1s 49ms/step - loss: 0.3262 - accuracy: 0.7645 - val_loss: 0.4659 - val_accuracy: 0.7123
# Epoch 72/250
# 11/11 [==============================] - ETA: 0s - loss: 0.3177 - accuracy: 0.7731
# Epoch 72: saving model to LSTM.h5
# 11/11 [==============================] - 1s 50ms/step - loss: 0.3177 - accuracy: 0.7731 - val_loss: 0.4590 - val_accuracy: 0.7205
# Epoch 73/250
# 11/11 [==============================] - ETA: 0s - loss: 0.3104 - accuracy: 0.7805
# Epoch 73: saving model to LSTM.h5
# 11/11 [==============================] - 1s 50ms/step - loss: 0.3104 - accuracy: 0.7805 - val_loss: 0.4570 - val_accuracy: 0.7235
# Epoch 74/250
# 11/11 [==============================] - ETA: 0s - loss: 0.3027 - accuracy: 0.7864
# Epoch 74: saving model to LSTM.h5
# 11/11 [==============================] - 1s 48ms/step - loss: 0.3027 - accuracy: 0.7864 - val_loss: 0.4546 - val_accuracy: 0.7254
# Epoch 75/250
# 11/11 [==============================] - ETA: 0s - loss: 0.2951 - accuracy: 0.7942
# Epoch 75: saving model to LSTM.h5
# 11/11 [==============================] - 1s 61ms/step - loss: 0.2951 - accuracy: 0.7942 - val_loss: 0.4491 - val_accuracy: 0.7269
# Epoch 76/250
# 10/11 [==========================>...] - ETA: 0s - loss: 0.2902 - accuracy: 0.7981
# Epoch 76: saving model to LSTM.h5
# 11/11 [==============================] - 1s 57ms/step - loss: 0.2879 - accuracy: 0.7989 - val_loss: 0.4457 - val_accuracy: 0.7336
# Epoch 77/250
# 11/11 [==============================] - ETA: 0s - loss: 0.2807 - accuracy: 0.8059
# Epoch 77: saving model to LSTM.h5
# 11/11 [==============================] - 1s 48ms/step - loss: 0.2807 - accuracy: 0.8059 - val_loss: 0.4418 - val_accuracy: 0.7347
# Epoch 78/250
# 11/11 [==============================] - ETA: 0s - loss: 0.2740 - accuracy: 0.8124
# Epoch 78: saving model to LSTM.h5
# 11/11 [==============================] - 1s 50ms/step - loss: 0.2740 - accuracy: 0.8124 - val_loss: 0.4396 - val_accuracy: 0.7366
# Epoch 79/250
# 11/11 [==============================] - ETA: 0s - loss: 0.2674 - accuracy: 0.8160
# Epoch 79: saving model to LSTM.h5
# 11/11 [==============================] - 1s 48ms/step - loss: 0.2674 - accuracy: 0.8160 - val_loss: 0.4356 - val_accuracy: 0.7388
# Epoch 80/250
# 11/11 [==============================] - ETA: 0s - loss: 0.2610 - accuracy: 0.8218
# Epoch 80: saving model to LSTM.h5
# 11/11 [==============================] - 1s 47ms/step - loss: 0.2610 - accuracy: 0.8218 - val_loss: 0.4322 - val_accuracy: 0.7433
# Epoch 81/250
# 11/11 [==============================] - ETA: 0s - loss: 0.2548 - accuracy: 0.8255
# Epoch 81: saving model to LSTM.h5
# 11/11 [==============================] - 1s 49ms/step - loss: 0.2548 - accuracy: 0.8255 - val_loss: 0.4307 - val_accuracy: 0.7444
# Epoch 82/250
# 11/11 [==============================] - ETA: 0s - loss: 0.2486 - accuracy: 0.8308
# Epoch 82: saving model to LSTM.h5
# 11/11 [==============================] - 1s 48ms/step - loss: 0.2486 - accuracy: 0.8308 - val_loss: 0.4247 - val_accuracy: 0.7507
# Epoch 83/250
# 11/11 [==============================] - ETA: 0s - loss: 0.2428 - accuracy: 0.8346
# Epoch 83: saving model to LSTM.h5
# 11/11 [==============================] - 1s 50ms/step - loss: 0.2428 - accuracy: 0.8346 - val_loss: 0.4254 - val_accuracy: 0.7519
# Epoch 84/250
# 11/11 [==============================] - ETA: 0s - loss: 0.2365 - accuracy: 0.8405
# Epoch 84: saving model to LSTM.h5
# 11/11 [==============================] - 1s 49ms/step - loss: 0.2365 - accuracy: 0.8405 - val_loss: 0.4214 - val_accuracy: 0.7575
# Epoch 85/250
# 11/11 [==============================] - ETA: 0s - loss: 0.2309 - accuracy: 0.8452
# Epoch 85: saving model to LSTM.h5
# 11/11 [==============================] - 1s 48ms/step - loss: 0.2309 - accuracy: 0.8452 - val_loss: 0.4177 - val_accuracy: 0.7597
# Epoch 86/250
# 11/11 [==============================] - ETA: 0s - loss: 0.2256 - accuracy: 0.8489
# Epoch 86: saving model to LSTM.h5
# 11/11 [==============================] - 1s 49ms/step - loss: 0.2256 - accuracy: 0.8489 - val_loss: 0.4155 - val_accuracy: 0.7597
# Epoch 87/250
# 11/11 [==============================] - ETA: 0s - loss: 0.2199 - accuracy: 0.8543
# Epoch 87: saving model to LSTM.h5
# 11/11 [==============================] - 1s 49ms/step - loss: 0.2199 - accuracy: 0.8543 - val_loss: 0.4142 - val_accuracy: 0.7627
# Epoch 88/250
# 11/11 [==============================] - ETA: 0s - loss: 0.2147 - accuracy: 0.8570
# Epoch 88: saving model to LSTM.h5
# 11/11 [==============================] - 1s 49ms/step - loss: 0.2147 - accuracy: 0.8570 - val_loss: 0.4108 - val_accuracy: 0.7668
# Epoch 89/250
# 11/11 [==============================] - ETA: 0s - loss: 0.2098 - accuracy: 0.8616
# Epoch 89: saving model to LSTM.h5
# 11/11 [==============================] - 1s 49ms/step - loss: 0.2098 - accuracy: 0.8616 - val_loss: 0.4085 - val_accuracy: 0.7687
# Epoch 90/250
# 11/11 [==============================] - ETA: 0s - loss: 0.2048 - accuracy: 0.8640
# Epoch 90: saving model to LSTM.h5
# 11/11 [==============================] - 1s 50ms/step - loss: 0.2048 - accuracy: 0.8640 - val_loss: 0.4071 - val_accuracy: 0.7687
# Epoch 91/250
# 11/11 [==============================] - ETA: 0s - loss: 0.1996 - accuracy: 0.8680
# Epoch 91: saving model to LSTM.h5
# 11/11 [==============================] - 1s 47ms/step - loss: 0.1996 - accuracy: 0.8680 - val_loss: 0.4063 - val_accuracy: 0.7694
# Epoch 92/250
# 11/11 [==============================] - ETA: 0s - loss: 0.1945 - accuracy: 0.8735
# Epoch 92: saving model to LSTM.h5
# 11/11 [==============================] - 1s 48ms/step - loss: 0.1945 - accuracy: 0.8735 - val_loss: 0.4029 - val_accuracy: 0.7731
# Epoch 93/250
# 11/11 [==============================] - ETA: 0s - loss: 0.1900 - accuracy: 0.8765
# Epoch 93: saving model to LSTM.h5
# 11/11 [==============================] - 1s 47ms/step - loss: 0.1900 - accuracy: 0.8765 - val_loss: 0.4002 - val_accuracy: 0.7780
# Epoch 94/250
# 11/11 [==============================] - ETA: 0s - loss: 0.1852 - accuracy: 0.8808
# Epoch 94: saving model to LSTM.h5
# 11/11 [==============================] - 1s 48ms/step - loss: 0.1852 - accuracy: 0.8808 - val_loss: 0.3993 - val_accuracy: 0.7757
# Epoch 95/250
# 11/11 [==============================] - ETA: 0s - loss: 0.1811 - accuracy: 0.8848
# Epoch 95: saving model to LSTM.h5
# 11/11 [==============================] - 1s 47ms/step - loss: 0.1811 - accuracy: 0.8848 - val_loss: 0.3984 - val_accuracy: 0.7813
# Epoch 96/250
# 11/11 [==============================] - ETA: 0s - loss: 0.1766 - accuracy: 0.8861
# Epoch 96: saving model to LSTM.h5
# 11/11 [==============================] - 1s 50ms/step - loss: 0.1766 - accuracy: 0.8861 - val_loss: 0.3948 - val_accuracy: 0.7836
# Epoch 97/250
# 11/11 [==============================] - ETA: 0s - loss: 0.1726 - accuracy: 0.8889
# Epoch 97: saving model to LSTM.h5
# 11/11 [==============================] - 1s 49ms/step - loss: 0.1726 - accuracy: 0.8889 - val_loss: 0.3938 - val_accuracy: 0.7832
# Epoch 98/250
# 11/11 [==============================] - ETA: 0s - loss: 0.1686 - accuracy: 0.8926
# Epoch 98: saving model to LSTM.h5
# 11/11 [==============================] - 1s 48ms/step - loss: 0.1686 - accuracy: 0.8926 - val_loss: 0.3916 - val_accuracy: 0.7858
# Epoch 99/250
# 11/11 [==============================] - ETA: 0s - loss: 0.1647 - accuracy: 0.8955
# Epoch 99: saving model to LSTM.h5
# 11/11 [==============================] - 1s 49ms/step - loss: 0.1647 - accuracy: 0.8955 - val_loss: 0.3905 - val_accuracy: 0.7896
# Epoch 100/250
# 11/11 [==============================] - ETA: 0s - loss: 0.1617 - accuracy: 0.8959
# Epoch 100: saving model to LSTM.h5
# 11/11 [==============================] - 1s 50ms/step - loss: 0.1617 - accuracy: 0.8959 - val_loss: 0.3874 - val_accuracy: 0.7914
# Epoch 101/250
# 11/11 [==============================] - ETA: 0s - loss: 0.1616 - accuracy: 0.8950
# Epoch 101: saving model to LSTM.h5
# 11/11 [==============================] - 1s 48ms/step - loss: 0.1616 - accuracy: 0.8950 - val_loss: 0.3871 - val_accuracy: 0.7896
# Epoch 102/250
# 11/11 [==============================] - ETA: 0s - loss: 0.1561 - accuracy: 0.8998
# Epoch 102: saving model to LSTM.h5
# 11/11 [==============================] - 1s 50ms/step - loss: 0.1561 - accuracy: 0.8998 - val_loss: 0.3839 - val_accuracy: 0.7907
# Epoch 103/250
# 11/11 [==============================] - ETA: 0s - loss: 0.1524 - accuracy: 0.9022
# Epoch 103: saving model to LSTM.h5
# 11/11 [==============================] - 1s 47ms/step - loss: 0.1524 - accuracy: 0.9022 - val_loss: 0.3848 - val_accuracy: 0.7937
# Epoch 104/250
# 11/11 [==============================] - ETA: 0s - loss: 0.1480 - accuracy: 0.9046
# Epoch 104: saving model to LSTM.h5
# 11/11 [==============================] - 1s 50ms/step - loss: 0.1480 - accuracy: 0.9046 - val_loss: 0.3827 - val_accuracy: 0.7937
# Epoch 105/250
# 11/11 [==============================] - ETA: 0s - loss: 0.1441 - accuracy: 0.9078
# Epoch 105: saving model to LSTM.h5
# 11/11 [==============================] - 1s 48ms/step - loss: 0.1441 - accuracy: 0.9078 - val_loss: 0.3813 - val_accuracy: 0.7959
# Epoch 106/250
# 11/11 [==============================] - ETA: 0s - loss: 0.1404 - accuracy: 0.9104
# Epoch 106: saving model to LSTM.h5
# 11/11 [==============================] - 1s 48ms/step - loss: 0.1404 - accuracy: 0.9104 - val_loss: 0.3803 - val_accuracy: 0.7955
# Epoch 107/250
# 11/11 [==============================] - ETA: 0s - loss: 0.1374 - accuracy: 0.9129
# Epoch 107: saving model to LSTM.h5
# 11/11 [==============================] - 1s 49ms/step - loss: 0.1374 - accuracy: 0.9129 - val_loss: 0.3788 - val_accuracy: 0.7993
# Epoch 108/250
# 11/11 [==============================] - ETA: 0s - loss: 0.1345 - accuracy: 0.9152
# Epoch 108: saving model to LSTM.h5
# 11/11 [==============================] - 1s 49ms/step - loss: 0.1345 - accuracy: 0.9152 - val_loss: 0.3764 - val_accuracy: 0.7989
# Epoch 109/250
# 11/11 [==============================] - ETA: 0s - loss: 0.1313 - accuracy: 0.9166
# Epoch 109: saving model to LSTM.h5
# 11/11 [==============================] - 1s 50ms/step - loss: 0.1313 - accuracy: 0.9166 - val_loss: 0.3778 - val_accuracy: 0.7996
# Epoch 110/250
# 11/11 [==============================] - ETA: 0s - loss: 0.1284 - accuracy: 0.9183
# Epoch 110: saving model to LSTM.h5
# 11/11 [==============================] - 1s 49ms/step - loss: 0.1284 - accuracy: 0.9183 - val_loss: 0.3755 - val_accuracy: 0.8030
# Epoch 111/250
# 11/11 [==============================] - ETA: 0s - loss: 0.1256 - accuracy: 0.9227
# Epoch 111: saving model to LSTM.h5
# 11/11 [==============================] - 1s 47ms/step - loss: 0.1256 - accuracy: 0.9227 - val_loss: 0.3762 - val_accuracy: 0.8045
# Epoch 112/250
# 11/11 [==============================] - ETA: 0s - loss: 0.1232 - accuracy: 0.9224
# Epoch 112: saving model to LSTM.h5
# 11/11 [==============================] - 1s 47ms/step - loss: 0.1232 - accuracy: 0.9224 - val_loss: 0.3751 - val_accuracy: 0.8000
# Epoch 113/250
# 11/11 [==============================] - ETA: 0s - loss: 0.1205 - accuracy: 0.9252
# Epoch 113: saving model to LSTM.h5
# 11/11 [==============================] - 1s 50ms/step - loss: 0.1205 - accuracy: 0.9252 - val_loss: 0.3737 - val_accuracy: 0.8067
# Epoch 114/250
# 11/11 [==============================] - ETA: 0s - loss: 0.1179 - accuracy: 0.9271
# Epoch 114: saving model to LSTM.h5
# 11/11 [==============================] - 1s 48ms/step - loss: 0.1179 - accuracy: 0.9271 - val_loss: 0.3731 - val_accuracy: 0.8071
# Epoch 115/250
# 11/11 [==============================] - ETA: 0s - loss: 0.1155 - accuracy: 0.9281
# Epoch 115: saving model to LSTM.h5
# 11/11 [==============================] - 1s 49ms/step - loss: 0.1155 - accuracy: 0.9281 - val_loss: 0.3734 - val_accuracy: 0.8049
# Epoch 116/250
# 11/11 [==============================] - ETA: 0s - loss: 0.1131 - accuracy: 0.9293
# Epoch 116: saving model to LSTM.h5
# 11/11 [==============================] - 1s 49ms/step - loss: 0.1131 - accuracy: 0.9293 - val_loss: 0.3714 - val_accuracy: 0.8093
# Epoch 117/250
# 11/11 [==============================] - ETA: 0s - loss: 0.1105 - accuracy: 0.9305
# Epoch 117: saving model to LSTM.h5
# 11/11 [==============================] - 1s 50ms/step - loss: 0.1105 - accuracy: 0.9305 - val_loss: 0.3704 - val_accuracy: 0.8078
# Epoch 118/250
# 11/11 [==============================] - ETA: 0s - loss: 0.1086 - accuracy: 0.9322
# Epoch 118: saving model to LSTM.h5
# 11/11 [==============================] - 1s 51ms/step - loss: 0.1086 - accuracy: 0.9322 - val_loss: 0.3706 - val_accuracy: 0.8142
# Epoch 119/250
# 11/11 [==============================] - ETA: 0s - loss: 0.1063 - accuracy: 0.9344
# Epoch 119: saving model to LSTM.h5
# 11/11 [==============================] - 1s 49ms/step - loss: 0.1063 - accuracy: 0.9344 - val_loss: 0.3701 - val_accuracy: 0.8104
# Epoch 120/250
# 11/11 [==============================] - ETA: 0s - loss: 0.1042 - accuracy: 0.9349
# Epoch 120: saving model to LSTM.h5
# 11/11 [==============================] - 1s 49ms/step - loss: 0.1042 - accuracy: 0.9349 - val_loss: 0.3708 - val_accuracy: 0.8134
# Epoch 121/250
# 11/11 [==============================] - ETA: 0s - loss: 0.1024 - accuracy: 0.9371
# Epoch 121: saving model to LSTM.h5
# 11/11 [==============================] - 1s 48ms/step - loss: 0.1024 - accuracy: 0.9371 - val_loss: 0.3708 - val_accuracy: 0.8146
# Epoch 122/250
# 11/11 [==============================] - ETA: 0s - loss: 0.1003 - accuracy: 0.9388
# Epoch 122: saving model to LSTM.h5
# 11/11 [==============================] - 1s 48ms/step - loss: 0.1003 - accuracy: 0.9388 - val_loss: 0.3693 - val_accuracy: 0.8127
# Epoch 123/250
# 11/11 [==============================] - ETA: 0s - loss: 0.0982 - accuracy: 0.9396
# Epoch 123: saving model to LSTM.h5
# 11/11 [==============================] - 1s 48ms/step - loss: 0.0982 - accuracy: 0.9396 - val_loss: 0.3689 - val_accuracy: 0.8149
# Epoch 124/250
# 11/11 [==============================] - ETA: 0s - loss: 0.0961 - accuracy: 0.9421
# Epoch 124: saving model to LSTM.h5
# 11/11 [==============================] - 1s 50ms/step - loss: 0.0961 - accuracy: 0.9421 - val_loss: 0.3696 - val_accuracy: 0.8131
# Epoch 125/250
# 11/11 [==============================] - ETA: 0s - loss: 0.0942 - accuracy: 0.9428
# Epoch 125: saving model to LSTM.h5
# 11/11 [==============================] - 1s 50ms/step - loss: 0.0942 - accuracy: 0.9428 - val_loss: 0.3679 - val_accuracy: 0.8138
# Epoch 126/250
# 11/11 [==============================] - ETA: 0s - loss: 0.0925 - accuracy: 0.9439
# Epoch 126: saving model to LSTM.h5
# 11/11 [==============================] - 1s 51ms/step - loss: 0.0925 - accuracy: 0.9439 - val_loss: 0.3688 - val_accuracy: 0.8127
# Epoch 127/250
# 11/11 [==============================] - ETA: 0s - loss: 0.0909 - accuracy: 0.9452
# Epoch 127: saving model to LSTM.h5
# 11/11 [==============================] - 1s 49ms/step - loss: 0.0909 - accuracy: 0.9452 - val_loss: 0.3694 - val_accuracy: 0.8138
# Epoch 128/250
# 11/11 [==============================] - ETA: 0s - loss: 0.0893 - accuracy: 0.9443
# Epoch 128: saving model to LSTM.h5
# 11/11 [==============================] - 1s 48ms/step - loss: 0.0893 - accuracy: 0.9443 - val_loss: 0.3683 - val_accuracy: 0.8168
# Epoch 129/250
# 11/11 [==============================] - ETA: 0s - loss: 0.0876 - accuracy: 0.9470
# Epoch 129: saving model to LSTM.h5
# 11/11 [==============================] - 1s 50ms/step - loss: 0.0876 - accuracy: 0.9470 - val_loss: 0.3693 - val_accuracy: 0.8153
# Epoch 130/250
# 11/11 [==============================] - ETA: 0s - loss: 0.0861 - accuracy: 0.9484
# Epoch 130: saving model to LSTM.h5
# 11/11 [==============================] - 1s 50ms/step - loss: 0.0861 - accuracy: 0.9484 - val_loss: 0.3690 - val_accuracy: 0.8179
# Epoch 130: early stopping

# %%
# create a figure with two subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))

# plot training & validation accuracy values
ax1.plot(history.history['accuracy'])
ax1.plot(history.history['val_accuracy'])
ax1.set_title('Train & Validation Accuracy')
ax1.set_ylabel('Accuracy')
ax1.set_xlabel('Epoch')
ax1.legend(['Train','Validation'], loc='upper left')

# plot training & validation loss values
ax2.plot(history.history['loss'])
ax2.plot(history.history['val_loss'])
ax2.set_title('Train loss & Validation loss')
ax2.set_ylabel('Loss')
ax2.set_xlabel('Epoch')
ax2.legend(['Train','Validation'], loc='upper left')

# adjust the spacing between subplots
plt.subplots_adjust(wspace=0.3)

# show the plot
plt.show()

# %%
def make_inference_models():
    
    encoder_model = tf.keras.models.Model(encoder_inputs, encoder_states)
    
    decoder_state_input_h = tf.keras.layers.Input(shape=( 200 ,))
    decoder_state_input_c = tf.keras.layers.Input(shape=( 200 ,))
    
    decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]
    
    decoder_outputs, state_h, state_c = decoder_lstm(
        decoder_embedding , initial_state=decoder_states_inputs)
    decoder_states = [state_h, state_c]
    decoder_outputs = decoder_dense(decoder_outputs)
    decoder_model = tf.keras.models.Model([decoder_inputs] + decoder_states_inputs,[decoder_outputs] + decoder_states)
    
    return encoder_model , decoder_model

# %% [markdown]
# ## 6) Talking with our Chatbot
#
# First, we define a method `str_to_tokens` which converts `str` questions to Integer tokens with padding.

# %%
def str_to_tokens( sentence : str ):
    words = sentence.lower().split()
    tokens_list = list()
    for word in words:
        tokens_list.append( tokenizer.word_index[ word ] ) 
    return preprocessing.sequence.pad_sequences( [tokens_list] , maxlen=maxlen_questions , padding='post')

# %%
enc_model , dec_model = make_inference_models()

for _ in range(10):
    states_values = enc_model.predict( str_to_tokens( input( 'Enter question : ' ) ),verbose=0 )
    empty_target_seq = np.zeros( ( 1 , 1 ) )
    empty_target_seq[0, 0] = tokenizer.word_index['start']
    stop_condition = False
    decoded_translation = ''
    while not stop_condition :
        dec_outputs , h , c = dec_model.predict([ empty_target_seq ] + states_values,verbose=0 )
        sampled_word_index = np.argmax( dec_outputs[0, -1, :] )
        sampled_word = None
        for word , index in tokenizer.word_index.items() :
            if sampled_word_index == index :
                decoded_translation += ' {}'.format( word )
                sampled_word = word
        
        if sampled_word == 'end' or len(decoded_translation.split()) > maxlen_answers:
            stop_condition = True
            
        empty_target_seq = np.zeros( ( 1 , 1 ) )  
        empty_target_seq[ 0 , 0 ] = sampled_word_index
        states_values = [ h , c ] 

    print( decoded_translation[:-3] )
# Out:
# WARNING:tensorflow:Model was constructed with shape (None, 85) for input KerasTensor(type_spec=TensorSpec(shape=(None, 85), dtype=tf.float32, name='input_2'), name='input_2', description="created by layer 'input_2'"), but it was called on an input with incompatible shape (None, 1).
#  hello how can i help you today
#  hello how can i help you today
#  the cost of hiring a driver in egypt varies depending on the length of your trip and the level of service you require prices are generally negotiable but be sure to agree on a price with the driver before starting your journey
#  the pyramids of giza are one of the most recognizable symbols of egypt and the ancient world they were built as tombs for pharaohs and their consorts during the old and middle kingdom periods
#  the best time of year to visit egypt is typically between november and march when the temperatures are cooler and the crowds are smaller however some travelers prefer to visit during the summer months to take advantage of the warm weather and longer daylight hours
#  who's an egyptian archaeologist's favourite person their mummy 😂😂
#  artificial intelligence is the branch of engineering and science devoted to constructing machines that think
#  what's a mummy's favourite music wrap 😂
#  what's a mummy's favourite music wrap 😂
#  what's a mummy's favourite music wrap 😂

# %% [markdown]
# ## 7) Conversion to TFLite ( Optional )
#
# We can convert our seq2seq model to a TensorFlow Lite model so that we can use it on edge devices.

# %%
converter = tf.lite.TFLiteConverter.from_keras_model( enc_model )
buffer = converter.convert()
open( 'enc_model.tflite' , 'wb' ).write( buffer )

converter = tf.lite.TFLiteConverter.from_keras_model( dec_model )
open( 'dec_model.tflite' , 'wb' ).write( buffer )
